# %%
import pandas as pd

# %%
df = pd.read_csv("hr_analytics.csv")
df.head()
# Out:
#    Age  Gender Department  MonthlyIncome  TotalWorkingYears  YearsAtCompany  \
# 0   50  Female         HR           4753                 14               8
# 1   36    Male        R&D          13123                  3               7
# 2   29    Male         HR          19376                 16              15
# 3   42    Male         HR           9588                 19              14
# 4   40    Male        R&D           9304                 18               8
#
#    JobSatisfaction  WorkLifeBalance OverTime Attrition
# 0                2                1      Yes        No
# 1                3                4       No        No
# 2                1                3      Yes        No
# 3                2                4       No       Yes
# 4                2                3       No       Yes

# %%
df.shape
# Out:
# (1000, 10)

# %%
df.dtypes
# Out:
# Age                   int64
# Gender               object
# Department           object
# MonthlyIncome         int64
# TotalWorkingYears     int64
# YearsAtCompany        int64
# JobSatisfaction       int64
# WorkLifeBalance       int64
# OverTime             object
# Attrition            object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Age                  0
# Gender               0
# Department           0
# MonthlyIncome        0
# TotalWorkingYears    0
# YearsAtCompany       0
# JobSatisfaction      0
# WorkLifeBalance      0
# OverTime             0
# Attrition            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape[0]  #number of employees
# Out:
# 1000

# %%
df["Department"]
# Out:
# 0         HR
# 1        R&D
# 2         HR
# 3         HR
# 4        R&D
#        ...
# 995    Sales
# 996    Sales
# 997       HR
# 998    Sales
# 999       HR
# Name: Department, Length: 1000, dtype: object

# %%
len(df)
# Out:
# 1000

# %%
df["Department"].unique()
# Out:
# array(['HR', 'R&D', 'Sales'], dtype=object)

# %%
df['Age'].mean()
# Out:
# np.float64(40.947)

# %%
df["Age"].min()
# Out:
# 22

# %%
df["Age"].max()
# Out:
# 59

# %%
print(df["Department"].value_counts())
# Out:
# Department
# HR       352
# Sales    343
# R&D      305
# Name: count, dtype: int64

# %%
df["YearsAtCompany"]>10
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 995    False
# 996     True
# 997    False
# 998    False
# 999    False
# Name: YearsAtCompany, Length: 1000, dtype: bool

# %%
df.groupby("Department")["MonthlyIncome"].mean()
# Out:
# Department
# HR       11604.042614
# R&D      11461.272131
# Sales    11417.247813
# Name: MonthlyIncome, dtype: float64
